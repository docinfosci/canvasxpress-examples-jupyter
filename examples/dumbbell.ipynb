# %% [markdown]
# ---
# jupytext:
#   formats: md:myst,ipynb
#   text_representation:
#     extension: .md
#     format_name: myst
#     format_version: 0.13
#     jupytext_version: 1.19.5
# ---
#
# # Dumbbell Chart Examples
#
# <a href="https://mybinder.org/v2/gh/docinfosci/canvasxpress-examples-jupyter/main?urlpath=lab/tree/examples/dumbbell.ipynb" target="_blank">Launch in MyBinder</a> for live interactive exploration

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

# %% [markdown]
# ## Example 1: Gender-Based Age Distribution: A Dumbbell Comparison
# Source: <https://www.canvasxpress.org/examples/dumbbell-1.html>
# A Dumbbell chart comparing age distributions between males and females across various countries. The chart displays three age groups: Combined, Male, and Female, with data points sorted in ascending order. The legend is divided into two columns for clarity.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "colors": ["grey", "blue", "pink"],
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "xAxis": ["Female", "Male"],
    "xAxis2Show": True,
    "xAxisShow": False,
    "xAxisTitle2": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Can you generate a Dumbbell chart showing age distributions for males and females across different countries? The chart should include three variables: Combined, Male, and Female. Use grey, blue, and pink colors respectively. Sort the data in ascending order. Include a legend with two columns and place it at the bottom. The x-axis should display 'Female' and 'Male' side by side, and the chart should be titled 'Gender-Based Age Distribution: A Dumbbell Comparison'. Please use CanvasXpress for the visualization.
#
# ## Example 2: Age Distribution Across Gender and Region
# Source: <https://www.canvasxpress.org/examples/dumbbell-2.html>
# This chart compares age distributions by gender across various regions, highlighting the largest age gap in Russia.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "colors": ["grey", "blue", "pink"],
    "dataPointSizeScaleFactor": 3.5,
    "graphOrientation": "vertical",
    "graphType": "Dumbbell",
    "highlightSmp": ["Russia"],
    "legendColumns": 2,
    "legendPosition": "bottom",
    "plotStyle": "open",
    "showDataValues": True,
    "subtitle": "The age difference between men and women is largest in Russia",
    "dataTextScaleFontFactor": 0.6,
    "smpTextRotate": 30,
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "titleFontStyle": "bold",
    "xAxis": ["Female", "Male"],
    "xAxisTitle": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please analyze the age distribution data comparing males and females across different regions using CanvasXpress. The chart is a vertical dumbbell plot with three variables: Combined, Male, and Female. The regions represented are Monaco, Japan, Germany, Italy, Greece, Hong Kong, Austria, Spain, Netherlands, Finland, South Korea, France, Poland, United Kingdom, Russia, Norway, United States, New Zealand, and China. The color scheme uses grey for the background, blue for one gender, and pink for the other. The legend is displayed in two columns at the bottom. The chart highlights Russia with the largest age difference between males and females. Please provide insights into gender age differences, regional variations, and the significance of the largest gap in Russia.
#
# ## Example 3: Age Distribution by Gender Across Countries
# Source: <https://www.canvasxpress.org/examples/dumbbell-3.html>
# A horizontal dumbbell plot comparing age distributions between males and females in various countries, showing the spread and overlap of age ranges.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "dumbbellType": "connected",
    "dataPointSizeScaleFactor": 3,
    "graphOrientation": "horizontal",
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "plotStyle": "open",
    "showDataValues": True,
    "dataTextScaleFontFactor": 0.5,
    "sortDir": "ascending",
    "theme": "wallStreetJournal",
    "title": "Age Range by Gender",
    "titleFontStyle": "bold",
    "xAxis": ["Female", "Male"],
    "xAxisTitle": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** You are a scientist generating a data visualization request using CanvasXpress. You have a horizontal dumbbell plot showing age distributions, with countries as samples and gender as the variable. The plot compares male and female age ranges across Monaco, Japan, Germany, Italy, Greece, Hong Kong, Austria, Spain, Netherlands, Finland, South Korea, France, Poland, United Kingdom, Russia, Norway, United States, New Zealand, and China. The dumbbells are connected and oriented horizontally, with data points scaled by a factor of 3. The legend is placed at the bottom in two columns, and data values are displayed. The chart uses a clean, professional wallStreetJournal theme with a bold title. Key observations include consistent age ranges in some countries and variability in others. This chart effectively illustrates gender-based age distribution differences across global regions.
#
# ## Example 4: Age Range by Gender
# Source: <https://www.canvasxpress.org/examples/dumbbell-4.html>
# A vertical Cleveland Dumbbell chart showing age ranges for different countries categorized by gender.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "dumbbellType": "cleveland",
    "graphOrientation": "vertical",
    "graphType": "Dumbbell",
    "legendColumns": 3,
    "legendPosition": "top",
    "smpTextRotate": 30,
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "titleFontStyle": "bold",
    "xAxis": ["Female", "Male", "Combined"],
    "xAxisTitle": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** I am a scientist requesting a data visualization showing age ranges by gender across different countries. The chart should use a vertical Cleveland Dumbbell layout, with the x-axis labeled as 'Female', 'Male', and 'Combined', and the y-axis showing age ranges. The chart should display three data series: 'Combined', 'Male', and 'Female'. The data provided includes age ranges for Monaco, Japan, Germany, Italy, Greece, Hong Kong, Austria, Spain, Netherlands, Finland, South Korea, France, Poland, United Kingdom, Russia, Norway, United States, New Zealand, and China. The chart should be sorted in ascending order and include a legend with 3 columns at the top. The x-axis text should be rotated 30 degrees for better readability. Notable patterns such as positive or negative trends and variability across countries should be clearly visible in the chart.
#
# ## Example 5: Gender Age Distribution Across Countries
# Source: <https://www.canvasxpress.org/examples/dumbbell-5.html>
# A horizontal dumbbell plot comparing the Combined age values between Male and Female for various countries.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "dumbbellType": "bullet",
    "dataPointSizeScaleFactor": 3,
    "graphOrientation": "horizontal",
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "plotStyle": "open",
    "showDataValues": True,
    "dataTextScaleFontFactor": 0.5,
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "titleFontStyle": "bold",
    "xAxis": ["Female", "Male"],
    "xAxisTitle": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** I would like to create a horizontal dumbbell plot showing the Combined age data for Male and Female across different countries. The x-axis represents the categories 'Male' and 'Female', with the y-axis listing the countries. The dumbbells are sorted in ascending order. The plot uses a bullet style, has a data point size scaled by 3, and the legend is positioned at the bottom with two columns. The chart type is a dumbbell, and the data values are displayed. The notable pattern is a decreasing trend in the Combined values as we move from left to right across the chart.
#
# ## Example 6: Age Distribution Between Males and Females Across Countries
# Source: <https://www.canvasxpress.org/examples/dumbbell-6.html>
# A Dumbbell chart showing the age distribution for males and females across various countries, with data points for the Combined category.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "colors": ["grey", "blue", "pink"],
    "dumbbellType": "arrow",
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "xAxis": ["Female", "Male"],
    "xAxis2Show": True,
    "xAxisShow": False,
    "xAxisTitle2": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please create a Dumbbell chart titled 'Age Distribution Between Males and Females Across Countries' using CanvasXpress. The chart should display the age ranges for males and females in Monaco, Japan, Germany, Italy, Greece, Hong Kong, Austria, Spain, Netherlands, Finland, South Korea, France, Poland, United Kingdom, Russia, Norway, United States, New Zealand, and China. The chart should use grey for the Combined category, blue for males, and pink for females. The dumbbell arrows should be set to point from higher to lower values. The x-axis should show 'Male' with the 'Female' category hidden, and the y-axis should show the age ranges. The legend should be placed at the bottom with two columns. The data should be sorted in ascending order.
#
# ## Example 7: Age Distribution by Gender Across Countries
# Source: <https://www.canvasxpress.org/examples/dumbbell-7.html>
# Shows the age distribution by gender (Male, Female, Combined) across various countries, with data points connected by lines in grey, blue, and pink.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "colors": ["grey", "blue", "pink"],
    "dumbbellType": "line",
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "sortDir": "ascending",
    "title": "Age Range by Gender",
    "xAxis": ["Female", "Male"],
    "xAxis2Show": True,
    "xAxisShow": False,
    "xAxisTitle2": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a dumbbell graph showing age distribution by gender (Male, Female, Combined) across different countries. Use grey, blue, and pink for the lines. The x-axis should display 'Female' and 'Male' with two legend columns. The graph title should be 'Age Distribution by Gender Across Countries' and the sort direction should be ascending. The x-axis should be labeled 'Age'.
#
# ## Example 8: Gender Age Distribution Across Countries
# Source: <https://www.canvasxpress.org/examples/dumbbell-8.html>
# A Dumbbell graph comparing male and female age distributions across various countries.

# %%
data = {
    "y": {
        "vars": ["Combined", "Male", "Female"],
        "smps": [
            "Monaco",
            "Japan",
            "Germany",
            "Italy",
            "Greece",
            "Hong Kong",
            "Austria",
            "Spain",
            "Netherlands",
            "Finland",
            "South Korea",
            "France",
            "Poland",
            "United Kingdom",
            "Russia",
            "Norway",
            "United States",
            "New Zealand",
            "China",
        ],
        "data": [
            [
                53.1,
                47.3,
                47.1,
                45.5,
                44.5,
                44.4,
                44,
                42.7,
                42.6,
                42.5,
                41.8,
                41.4,
                40.7,
                40.5,
                39.6,
                39.2,
                38.1,
                37.9,
                37.4,
            ],
            [
                51.7,
                46,
                46,
                44.4,
                43.5,
                43.5,
                42.8,
                41.5,
                41.5,
                40.9,
                40.2,
                39.6,
                39,
                39.3,
                36.6,
                38.4,
                36.8,
                37.1,
                36.5,
            ],
            [
                54.5,
                48.7,
                48.2,
                46.5,
                45.6,
                45,
                45.1,
                43.9,
                43.6,
                44.3,
                43.4,
                43.1,
                42.4,
                41.7,
                42.5,
                40,
                39.4,
                38.8,
                38.4,
            ],
        ],
    }
}
config = {
    "colors": ["grey", "blue", "pink"],
    "connectByColor": "#ffffff",
    "dataPointSizeScaleFactor": 3,
    "dumbbellType": "lineConnected",
    "graphOrientation": "vertical",
    "graphType": "Dumbbell",
    "legendColumns": 2,
    "legendPosition": "bottom",
    "smpTextRotate": 30,
    "sortDir": "ascending",
    "theme": "wallStreetJournal",
    "title": "Age Range by Gender",
    "xAxis": ["Female", "Male"],
    "xAxisTitle": "Age",
}

cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please create a Dumbbell graph titled 'Gender Age Distribution Across Countries' showing the age distribution for Male and Female in each country. The data includes samples from Monaco, Japan, Germany, Italy, Greece, Hong Kong, Austria, Spain, Netherlands, Finland, South Korea, France, Poland, United Kingdom, Russia, Norway, United States, New Zealand, and China. The x-axis represents Male and Female, the y-axis represents age, with the Combined data point as the base. Use blue for Male, pink for Female, and grey for the Combined line. Include a legend with two columns, place it at the bottom, rotate the sample names by 30 degrees, sort the data in ascending order, and use the Wall Street Journal theme. Show the key parameters as Combined, Male, Female, and highlight the notable differences in age distribution between genders in some countries.
