# %% [markdown]
# ---
# jupytext:
#   formats: md:myst,ipynb
#   text_representation:
#     extension: .md
#     format_name: myst
#     format_version: 0.13
#     jupytext_version: 1.19.5
# ---
#
# # Radar Chart Examples
#
# <a href="https://mybinder.org/v2/gh/docinfosci/canvasxpress-examples-jupyter/main?urlpath=lab/tree/examples/radar.ipynb" target="_blank">Launch in MyBinder</a> for live interactive exploration

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

# %% [markdown]
# ## Example 1: Radar Chart: Performance Analysis
# Source: <https://www.canvasxpress.org/examples/radar-1.html>
# A radar chart visualizing performance metrics across four magnitudes with specific factors on the axes.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'ringGraphType': ['line'],
  'showTransition': False,
  'title': 'Radar - Line',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please create a radar chart using CanvasXpress to visualize the performance metrics. The chart should display four magnitudes (Magnitude1 and Magnitude2) across four variables (V1, V2, V3, V4). The x-axis should represent the factors (Factor1 to Factor6), and the chart should use the Bootstrap color scheme. Include notable patterns such as the line type (radar) and the specific factor levels for each magnitude. Ensure the legend is clearly marked with the provided data points.
#
# ## Example 2: Radar Chart: Area Visualization Comparing Four Variables Across Two Magnitudes
# Source: <https://www.canvasxpress.org/examples/radar-2.html>
# A radar chart displaying the area visualization of four variables (V1-V4) across two magnitudes (Magnitude1 and Magnitude2). The chart uses different colors to represent each magnitude, and the data structure includes multiple factors with varying levels.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'legendPosition': 'top',
  'ringGraphType': ['area'],
  'showTransition': False,
  'title': 'Radar - Area',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please create a radar chart showing the area visualization of four variables (V1-V4) across two magnitudes (Magnitude1 and Magnitude2). The chart should use different colors for each magnitude and display the data structure with its factors and levels. The radar type should be area-based, and the chart should include a legend for clarity. Please ensure the cumulative data is shown without overlapping rings.
#
# ## Example 3: Radar - Bar Chart
# Source: <https://www.canvasxpress.org/examples/radar-3.html>
# A radar chart displaying bar elements with magnitude values. The chart uses four factors (Lev, Lev, Lev, and Lev) and four magnitudes (Magnitude1 and Magnitude2). Each spoke represents a factor, and each bar within a spoke represents a magnitude value. The chart uses Bootstrap colors and is configured with a radar layout.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'ringGraphType': ['bar'],
  'showTransition': False,
  'title': 'Radar - Bar',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a radar chart using Bootstrap colors to display a bar chart with four factors (Lev, Lev, Lev, Lev) and four magnitudes (Magnitude1 and Magnitude2). Each spoke should represent a factor (Lev : 1, Lev : 2, Lev : 3, Lev : 1, Lev : 2, Lev : 3), each bar within a spoke should represent a magnitude value (5, 10, 25, 40, 45, 50; 95, 80, 75, 70, 55, 40; 25, 30, 45, 60, 65, 70; 55, 40, 35, 30, 15, 1). The chart should be circular with a radar layout, using Bootstrap color scheme, and include a legend key background color of rgba(255,255,255,0). The chart should highlight key parameters such as the circular arc, circular rotation, and ring graph type.
#
# ## Example 4: Radar - Scatter Chart with Multiple Magnitudes
# Source: <https://www.canvasxpress.org/examples/radar-4.html>
# A radar chart displaying four magnitudes across six factors, with annotations showing partial data points.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'legendPosition': 'top',
  'ringGraphType': ['dot'],
  'showTransition': False,
  'title': 'Radar - Scatter',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Could you please create a Radar chart showing 'Radar - Scatter' with the following specifications? The chart should have four datasets (Magnitude1 to Magnitude4) plotted against six factors (Factor1 to Factor6) as axes. Use the Bootstrap color scheme, include a legend with a white background, and show annotations for each data point. Note that some annotations are incomplete and should be clearly marked in the chart.
#
# ## Example 5: Radar Chart Showing Stacked Data for V1 to V4
# Source: <https://www.canvasxpress.org/examples/radar-5.html>
# A radar chart displaying the stacked data for variables V1 to V4, illustrating the levels and magnitudes of each factor.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'legendPosition': 'top',
  'ringGraphType': ['stacked'],
  'showTransition': False,
  'title': 'Radar - Stacked',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** To visualize the data, create a radar chart with a circular arc of 360 degrees. Use a stacked layout to display the data points for V1, V2, V3, and V4. Categorize the data using the provided levels for Factor1 to Factor3, numerical values for Factors 4, 5, and 6, and assign different colors for clarity. Position the legend at the top and ensure the chart is Bootstrap-themed. Each section should represent the data for each variable, with the radar graph showing the magnitude of each factor in a circular format.
#
# ## Example 6: Radar Chart Analysis
# Source: <https://www.canvasxpress.org/examples/radar-6.html>
# A radar chart displaying trends across four factors (Lev : 1, 2, 3, A, B, X) and four magnitude categories (Magnitude1 and Magnitude2). The chart uses a half-circle layout with Bootstrap color scheme and 180-degree circular rotation to visualize the data relationships.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 180,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'ringGraphType': ['line'],
  'showTransition': False,
  'title': 'Half Radar',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Please create a radar chart visualization showing the trends across four factors (Lev : 1, 2, 3, A, B, X) and four magnitude categories (Magnitude1 and Magnitude2). The chart should use a half-circle layout with a 180-degree circular rotation, displaying data points for each of the six samples (S1 to S6) across four variables (V1 to V4). The chart should use Bootstrap color scheme for the data lines and ensure the legend has a white background. The chart should highlight the relationships between the variables and show the magnitude trends for each sample. Please ensure the chart is interactive and allows for zooming and tooltips for detailed analysis.
#
# ## Example 7: Interactive Radar Plot Showing Magnitude and Sample Data
# Source: <https://www.canvasxpress.org/examples/radar-7.html>
# An interactive radar plot displaying data across four variables (V1-V4) with four magnitude categories (Magnitude1-Magnitude2) and six sample points (S1-S6). The chart uses circular arcs and lines to visualize data trends, with a Bootstrap color scheme and legend positioned at the top.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 180,
  'circularRotate': -90,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'legendPosition': 'top',
  'ringGraphType': ['line'],
  'showTransition': False,
  'title': 'Rotated Half Radar',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Could you please create an interactive radar plot using CanvasXpress that visualizes the data across four variables (V1-V4) with four magnitude categories (Magnitude1-Magnitude2) and six sample points (S1-S6)? The plot should display data trends using circular arcs and lines, with a Bootstrap color scheme and a legend positioned at the top. The chart should be titled 'Interactive Radar Plot Showing Magnitude and Sample Data' and include a short description explaining the data structure and key parameters.
#
# ## Example 8: Radar Chart with Overlay Comparisons
# Source: <https://www.canvasxpress.org/examples/radar-8.html>
# A radar chart displaying four variables (V1-V4) on the x-axis and four samples (S1-S6) on the y-axis, with circular overlays for comparison.

# %%
data = {
  'x': {
    'Factor1': ['Lev : 1', 'Lev : 2', 'Lev : 3', 'Lev : 1', 'Lev : 2', 'Lev : 3'],
    'Factor2': ['Lev : A', 'Lev : B', 'Lev : A', 'Lev : B', 'Lev : A', 'Lev : B'],
    'Factor3': ['Lev : X', 'Lev : X', 'Lev : Y', 'Lev : Y', 'Lev : Z', 'Lev : Z'],
    'Factor4': [5, 10, 15, 20, 25, 30],
    'Factor5': [8, 16, 24, 32, 40, 48],
    'Factor6': [10, 20, 30, 40, 50, 60],
  },
  'y': {
    'data': [
      [5, 10, 25, 40, 45, 50],
      [95, 80, 75, 70, 55, 40],
      [25, 30, 45, 60, 65, 70],
      [55, 40, 35, 30, 15, 1],
    ],
    'desc': ['Magnitude1', 'Magnitude2'],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2', 'V3', 'V4'],
  },
  'z': {
    'Annt1': ['Desc : 1', 'Desc : 2', 'Desc : 3', 'Desc : 4'],
    'Annt2': ['Desc : A', 'Desc : B', 'Desc : A', 'Desc : B'],
    'Annt3': ['Desc : X', 'Desc : X', 'Desc : Y', 'Desc : Y'],
    'Annt4': [5, 10, 15, 20],
    'Annt5': [8, 16, 24, 32],
    'Annt6': [10, 20, 30, 40],
  },
}
config = {
  'circularArc': 360,
  'circularRotate': 0,
  'circularType': 'radar',
  'colorScheme': 'Bootstrap',
  'graphType': 'Circular',
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'objectBorderColor': 'rgb(0,0,0)',
  'ringGraphType': ['line'],
  'showTransition': False,
  'smpOverlays': ['Factor3', '-', 'Factor1', 'Factor2'],
  'title': 'Radar with Overlays',
  'transitionStep': 50,
  'transitionTime': 1500,
  'xAxis': ['V1', 'V2', 'V3', 'V4'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** You are a scientist analyzing data using CanvasXpress. You have generated a radar chart showing four variables (V1-V4) on the x-axis and four samples (S1-S6) on the y-axis. The chart uses a circular layout with line overlays for comparison. The legend provides color coding for different data categories. Key parameters include circular rotation, radar type, and line graph display. Notable patterns show variations in the data points across samples and variables.
#
# ## Example 9: Circular Scatter Plot of Radar Data
# Source: <https://www.canvasxpress.org/examples/radar-9.html>
# A circular radar plot displaying data points with varying sizes and colors, showing relationships between size and radius values in a circular layout.

# %%
data = {
  'x': {
    'size': [93, 55, 57, 23, 66, 23, 53, 60, 41, 92, 34, 94, 93, 1, 61, 60, 89, 75, 57, 94, 63, 13, 19, 87, 57, 2, 57, 12, 38, 20],
    'color': ['red', 'red', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'brown', 'brown', 'brown', 'brown', 'brown', 'brown', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green', 'green'],
    'alpha': [0.44, 0.5, 0.41, 0.21, 0.22, 0.23, 0.73, 0.42, 0.58, 0.49, 0.43, 0.73, 0.56, 0.3, 0.97, 0.22, 0.14, 0.61, 0.49, 0.18, 0.11, 0.54, 0.29, 0.1, 0.49, 0.63, 0.04, 0.5, 0.08, 0.79],
  },
  'y': {
    'data': [
      [2, 1, 5, 3, 5, 1, 3, 1, 4, 5, 3, 2, 2, 4, 2, 5, 1, 4, 5, 1, 4, 3, 5, 3, 4, 2, 2, 4, 3, 1],
      [0.25, 1.07, 1.17, 1.18, 1.53, 2.18, 2.74, 2.91, 2.93, 3, 3.12, 3.27, 3.84, 4.01, 4.07, 4.08, 4.32, 4.42, 4.76, 5.05, 5.18, 5.41, 5.47, 5.49, 5.69, 5.81, 5.91, 5.94, 6.1, 6.18],
    ],
    'smps': ['smp1', 'smp2', 'smp3', 'smp4', 'smp5', 'smp6', 'smp7', 'smp8', 'smp9', 'smp10', 'smp11', 'smp12', 'smp13', 'smp14', 'smp15', 'smp16', 'smp17', 'smp18', 'smp19', 'smp20', 'smp21', 'smp22', 'smp23', 'smp24', 'smp25', 'smp26', 'smp27', 'smp28', 'smp29', 'smp30'],
    'vars': ['radius', 'radians'],
  },
}
config = {
  'graphType': 'Circular',
  'circularTrackGraphType': ['scatter'],
  'circularType': 'radar',
  'colorBy': 'color',
  'colorKey': {
    'color': {
      'red': '#FF0000',
      'blue': '#0000FF',
      'green': '#00FF00',
      'brown': '#A52A2A',
    },
  },
  'sizeBy': 'size',
  'rAxis': 'radians',
  'yAxis': ['radius'],
  'setMinY': 0,
  'setMaxY': 5,
  'setMinR': 0,
  'setMaxR': 6.283185307179586,
  'showSampleNames': False,
  'showLegend': True,
  'rAxisShow': True,
  'rAxisPercentShow': False,
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Visualize the data as a circular radar plot with points varying in size based on the 'size' array and color based on the 'color' array. The 'alpha' array indicates point transparency. Include a legend to explain the color coding and size variations. Use CanvasXpress to create the visualization, highlighting the key parameters such as size, color, and the circular radar layout with radial and radius axes.
