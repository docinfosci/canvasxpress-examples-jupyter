# %% [markdown]
# ---
# jupytext:
#   formats: md:myst,ipynb
#   text_representation:
#     extension: .md
#     format_name: myst
#     format_version: 0.13
#     jupytext_version: 1.19.5
# ---
#
# # Waterfall Chart Examples
#
# **[Launch in MyBinder](https://mybinder.org/docinfosci/canvasxpress-examples-jupyter/main?urlpath=lab/tree/examples/waterfall.ipynb)** for live interactive exploration

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

# %% [markdown]
# ## Example 1: Waterfall plot showing changes in QoL scores by treatment
# Source: <https://www.canvasxpress.org/examples/waterfall-1.html>
# A vertical bar plot displaying the change in QoL scores from baseline for different treatments. The x-axis represents the treatments (Trt-1 and Trt-2), and the y-axis shows the QoL score changes in percentages.

# %%
data = {
  'x': {
    'Treatment': ['Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-1'],
  },
  'y': {
    'data': [
      [109.09, 89.65, 57.14, 54.54, 52.38, 47.05, 42.1, 37.28, 36.66, 36.53, 32.65, 32.07, 31.48, 29.62, 29.5, 29.16, 28.57, 28, 27.45, 23.07, 21.56, 20.75, 19.23, 18.75, 17.64, 17.3, 16, 15.25, 15.15, 14.54, 13.04, 11.76, 10.9, 7.4, 7.14, 7.01, 6.89, 4.61, 3.22, 2.94, 1.88, 0, 0, -1.67, -3.71, -3.93, -4.23, -4.42, -4.69, -5.18, -6.67, -10.53, -12.31, -19.24, -29.89],
    ],
    'smps': ['Sub-253', 'Sub-337', 'Sub-193', 'Sub-313', 'Sub-217', 'Sub-37', 'Sub-169', 'Sub-55', 'Sub-19', 'Sub-145', 'Sub-103', 'Sub-49', 'Sub-205', 'Sub-97', 'Sub-79', 'Sub-67', 'Sub-115', 'Sub-325', 'Sub-43', 'Sub-109', 'Sub-91', 'Sub-157', 'Sub-151', 'Sub-343', 'Sub-139', 'Sub-319', 'Sub-85', 'Sub-181', 'Sub-175', 'Sub-127', 'Sub-271', 'Sub-163', 'Sub-211', 'Sub-187', 'Sub-307', 'Sub-73', 'Sub-229', 'Sub-235', 'Sub-241', 'Sub-31', 'Sub-223', 'Sub-25', 'Sub-295', 'Sub-301', 'Sub-265', 'Sub-331', 'Sub-121', 'Sub-199', 'Sub-133', 'Sub-259', 'Sub-277', 'Sub-355', 'Sub-283', 'Sub-1', 'Sub-61'],
    'vars': ['QoL-Score'],
  },
}
config = {
  'graphOrientation': 'vertical',
  'graphType': 'Bar',
  'showLegend': False,
  'showSampleNames': False,
  'title': 'Waterfall plot changes in QoL scores',
  'xAxisTitle': 'Change from baseline (%) in QoL score',
  'xAxis': ['QoL-Score'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a vertical bar plot titled 'Waterfall plot showing changes in QoL scores by treatment' with the x-axis labeled 'Change from baseline (%) in QoL score' and the y-axis showing the QoL score changes. The chart should display data for different treatments (Trt-1 and Trt-2) with values ranging from 7.01% to 109.09%. Include a legend if necessary and highlight key patterns in the data.
#
# ## Example 2: Change in QoL Scores by Treatment (Vertical Bar Chart)
# Source: <https://www.canvasxpress.org/examples/waterfall-2.html>
# A vertical bar chart comparing the percentage change in Quality of Life (QoL) scores across different treatments.

# %%
data = {
  'x': {
    'Treatment': ['Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-1', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-2', 'Trt-1', 'Trt-1'],
  },
  'y': {
    'data': [
      [109.09, 89.65, 57.14, 54.54, 52.38, 47.05, 42.1, 37.28, 36.66, 36.53, 32.65, 32.07, 31.48, 29.62, 29.5, 29.16, 28.57, 28, 27.45, 23.07, 21.56, 20.75, 19.23, 18.75, 17.64, 17.3, 16, 15.25, 15.15, 14.54, 13.04, 11.76, 10.9, 7.4, 7.14, 7.01, 6.89, 4.61, 3.22, 2.94, 1.88, 0, 0, -1.67, -3.71, -3.93, -4.23, -4.42, -4.69, -5.18, -6.67, -10.53, -12.31, -19.24, -29.89],
    ],
    'smps': ['Sub-253', 'Sub-337', 'Sub-193', 'Sub-313', 'Sub-217', 'Sub-37', 'Sub-169', 'Sub-55', 'Sub-19', 'Sub-145', 'Sub-103', 'Sub-49', 'Sub-205', 'Sub-97', 'Sub-79', 'Sub-67', 'Sub-115', 'Sub-325', 'Sub-43', 'Sub-109', 'Sub-91', 'Sub-157', 'Sub-151', 'Sub-343', 'Sub-139', 'Sub-319', 'Sub-85', 'Sub-181', 'Sub-175', 'Sub-127', 'Sub-271', 'Sub-163', 'Sub-211', 'Sub-187', 'Sub-307', 'Sub-73', 'Sub-229', 'Sub-235', 'Sub-241', 'Sub-31', 'Sub-223', 'Sub-25', 'Sub-295', 'Sub-301', 'Sub-265', 'Sub-331', 'Sub-121', 'Sub-199', 'Sub-133', 'Sub-259', 'Sub-277', 'Sub-355', 'Sub-283', 'Sub-1', 'Sub-61'],
    'vars': ['QoL-Score'],
  },
}
config = {
  'graphOrientation': 'vertical',
  'graphType': 'Bar',
  'segregateSamplesBy': ['Treatment'],
  'showLegend': False,
  'showSampleNames': False,
  'stripBackgroundBorderColor': 'rgb(0,0,0)',
  'stripTextColor': 'rgb(0,0,0)',
  'title': 'Waterfall plot changes in QoL scores',
  'xAxisTitle': 'Change from baseline (%) in QoL score',
  'xAxis': ['QoL-Score'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a vertical bar chart titled 'Change in QoL Scores by Treatment' showing the percentage change in QoL scores on the y-axis and treatment type on the x-axis. Each bar represents a treatment group (Trt-1 and Trt-2). The chart uses black color for the bars and black text. The x-axis is labeled 'Change from baseline (%) in QoL score'. The chart should not display a legend or sample names. Look for patterns in the distribution of QoL changes between the treatments.
#
# ## Example 3: Distribution of Tumor Shrinkage Across Tissues and Statuses in a Clinical Trial
# Source: <https://www.canvasxpress.org/examples/waterfall-3.html>
# A vertical bar chart showing the distribution of tumor shrinkage percentages across different tissues and statuses. The x-axis represents tumor status (PD, SD, PR) and tissue type, while the y-axis represents the percentage of tumor shrinkage. The chart uses a NEJM color scheme and includes notable patterns in the distribution of shrinkage values.

# %%
data = {
  'x': {
    'Status': ['PD', 'PD', 'PD', 'PD', 'PD', 'PD', 'SD', 'PD', 'PD', 'PD', 'PD', 'PD', 'SD', 'SD', 'SD', 'PR'],
    'Tissue': ['Pancreas', 'Pancreas', 'Pancreas', 'Colrectal', 'Breast', 'Colrectal', 'Colrectal', 'Colrectal', 'Billiary tract', 'Colrectal', 'Esophagus', 'Billiary tract', 'Billiary tract', 'Billiary tract', 'Colrectal', 'Billiary tract'],
  },
  'y': {
    'data': [
      [115, 75, 39, 23, 22, 15, 12, 10, 10, 10, 5, 4, 2, -8, -11, -31],
    ],
    'smps': ['1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '1010', '1011', '1012', '1013', '1014', '1015', '1016'],
    'vars': ['Shrinkage'],
  },
}
config = {
  'colorBy': 'Tissue',
  'colorScheme': 'NEJM',
  'graphOrientation': 'vertical',
  'graphType': 'Bar',
  'legendInside': True,
  'legendKeyBackgroundBorderColor': 'rgba(255,255,255,0)',
  'legendKeyBackgroundColor': 'rgba(255,255,255,0)',
  'legendPosition': 'topRight',
  'showSampleNames': False,
  'smpOverlayProperties': {
    'Status': {
      'position': 'bottom',
      'scheme': 'White',
    },
  },
  'smpOverlays': ['Status'],
  'title': 'Clinical Trial',
  'xAxis2Show': False,
  'xAxisTitle': 'Best tumor shrinkage (%)',
  'xAxis': ['Shrinkage'],
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a vertical bar chart using CanvasXpress showing the distribution of tumor shrinkage percentages across different tissues and statuses. The x-axis should display the tumor status (PD, SD, PR) and tissue type, while the y-axis should represent the percentage of tumor shrinkage. Use the NEJM color scheme for the bars, include a legend inside the chart, and ensure the key parameters such as shrinkage values and tissue status are clearly labeled. Highlight any notable patterns in the distribution of tumor shrinkage across tissues and statuses.
#
# ## Example 4: Waterfall Analysis of Variable V1 Across Six Samples
# Source: <https://www.canvasxpress.org/examples/waterfall-4.html>
# A vertical Waterfall chart showing the changes in Variable V1 across six samples (S1 to S6). The chart displays the cumulative values for each sample, with positive and negative deltas indicated.

# %%
data = {
  'y': {
    'data': [
      [83, -44, 55, -60, 40, 0],
    ],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1'],
  },
}
config = {
  'graphOrientation': 'vertical',
  'graphType': 'Waterfall',
  'showLegend': False,
  'smpTextRotate': 90,
  'smpTitle': 'Samples',
  'title': 'Traditional Waterfall',
  'xAxis': ['V1'],
  'xAxisTitle': 'Value',
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** Generate a vertical Waterfall chart for Variable V1 across six samples (S1 to S6). The chart should show the cumulative changes with positive values in green and negative values in red. The x-axis should represent the samples (S1 to S6) and the y-axis should represent the value of Variable V1. Include key parameters such as the initial value, positive and negative deltas, and the final value. Highlight any notable patterns in the data.
#
# ## Example 5: Traditional Waterfall
# Source: <https://www.canvasxpress.org/examples/waterfall-5.html>
# A Waterfall chart comparing two variables (V1 and V2) across six samples (S1 to S6). The chart shows the distribution of values, with positive values in green and negative values in red, oriented vertically with sample names rotated 90 degrees for clarity.

# %%
data = {
  'y': {
    'data': [
      [83, -44, 55, -60, 40, 0],
      [50, 20, -30, 60, -10, 0],
    ],
    'smps': ['S1', 'S2', 'S3', 'S4', 'S5', 'S6'],
    'vars': ['V1', 'V2'],
  },
}
config = {
  'graphOrientation': 'vertical',
  'graphType': 'Waterfall',
  'smpTextRotate': 90,
  'smpTitle': 'Samples',
  'title': 'Traditional Waterfall',
  'xAxis': ['V1', 'V2'],
  'xAxisTitle': 'Value',
}
cx = CanvasXpress(data=data, config=config)
graph(cx)

# %% [markdown]
# **Agent Prompt:** I would like to visualize the data showing two variables (V1 and V2) across six samples (S1 to S6) using a vertical Waterfall chart. The data indicates positive and negative values, with S1 having 83 and 50 for V1 and V2 respectively, and S6 having 0 for both. I need a clear legend, axes labeled with variable names, and key parameters like minimum and maximum values. Please ensure the chart shows both positive and negative trends.
